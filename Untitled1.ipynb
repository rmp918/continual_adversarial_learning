# %%
# libraries
import copy
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
import numpy as np
import torch
import torch.nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision.datasets as datasets
from tqdm import tqdm

matplotlib.rcParams['figure.figsize'] = [18, 12]

# code from this library - import the lines module
import loss_landscapes
import loss_landscapes.metrics

# %%
# training hyperparameters
IN_DIM = 28 * 28
OUT_DIM = 10
LR = 10 ** -2
BATCH_SIZE = 512
EPOCHS = 25
# contour plot resolution
STEPS = 100

# %%
class MLPSmall(torch.nn.Module):
    """ Fully connected feed-forward neural network with one hidden layer. """
    def __init__(self, x_dim, y_dim):
        super().__init__()
        self.linear_1 = torch.nn.Linear(x_dim, 32)
        self.linear_2 = torch.nn.Linear(32, y_dim)

    def forward(self, x):
        h = F.relu(self.linear_1(x))
        return F.softmax(self.linear_2(h), dim=1)


class Flatten(object):
    """ Transforms a PIL image to a flat numpy array. """
    def __call__(self, sample):
        return np.array(sample, dtype=np.float32).flatten()    
    

def train(model, optimizer, criterion, train_loader, epochs):
    """ Trains the given model with the given optimizer, loss function, etc. """
    model.train()
    # train model
    for _ in tqdm(range(epochs), 'Training'):
        for count, batch in enumerate(train_loader, 0):
            optimizer.zero_grad()
            x, y = batch

            pred = model(x)
            loss = criterion(pred, y)
            loss.backward()
            optimizer.step()

    model.eval()

# %%
# download MNIST and setup data loaders
mnist_train = datasets.MNIST(root='../data', train=True, download=True, transform=Flatten())
train_loader = torch.utils.data.DataLoader(mnist_train, batch_size=BATCH_SIZE, shuffle=False)

# define model
model = MLPSmall(IN_DIM, OUT_DIM)
optimizer = optim.Adam(model.parameters(), lr=LR)
criterion = torch.nn.CrossEntropyLoss()

# %%
# stores the initial point in parameter space
model_initial = copy.deepcopy(model)

# %%
train(model, optimizer, criterion, train_loader, EPOCHS)

model_final = copy.deepcopy(model)
# Out:
# Training: 100%|██████████| 25/25 [02:48<00:00,  6.75s/it]

# %%
# data that the evaluator will use when evaluating loss
x, y = iter(train_loader).__next__()
metric = loss_landscapes.metrics.Loss(criterion, x, y)

# compute loss data
loss_data = loss_landscapes.linear_interpolation(model_initial, model_final, metric, STEPS, deepcopy_model=True)

# %%
loss_data1 = np.array([1.43,1.19,1.14,1.06,1.03,0.992,1.01,0.962,0.924,0.866,0.881,0.845,0.827,0.814,0.807,0.788,0.774,0.739,0.716,0.764,0.712,0.693,0.676,0.66,0.672,0.649,0.621,0.597,0.573,0.582,0.553,0.55,0.56,0.525,0.543,0.574,0.539,0.501,0.666,0.71,0.597,0.481,0.504,0.49,0.439,0.562,0.493,0.577,0.386,0.315,0.295,0.287,0.262,0.286,0.244,0.239,0.222,0.205,0.225,0.201,0.204,0.196,0.188,0.187,0.178,0.171,0.152,0.149,0.147,0.163,0.163,0.165,0.134,0.123,0.138,0.121,0.134,0.11,
0.11,0.0989,0.0997,0.0937,0.0953,0.0879,0.0911,0.099,0.0961,0.0869,0.0785,0.0861,0.0767,0.0739,0.0891,0.0811,0.0962,0.0954,0.0875,0.0844,0.0756,0.0748
])

# %%
loss_data2 = np.array([
    1.32,
1.28,
1.11,
1.18,
#  2.06465197 2.06465244 2.0646503  2.06465268 2.06657624 2.06855941
#  2.07051182 2.07051206 2.07051206 2.07051206]

# %%
s = np.arange(0,100)
plt.plot(s, loss_data1, label = "Train")
plt.plot(s, loss_data2, label = "Val")
#plt.plot([1/STEPS * i for i in range(STEPS)], loss_data1)
plt.title('Training Loss with PackNet on cifar100')
plt.xlabel('epoch')
plt.ylabel('Loss')
axes = plt.gca()
# axes.set_ylim([2.300,2.325])
plt.legend()
#plt.show()
plt.savefig('Training Loss with PackNet.png')

# %%
plt.plot([1/STEPS * i for i in range(STEPS)], loss_data1)
plt.title('Linear Interpolation of Loss with PackNet on cifar100')
plt.xlabel('epoch')
plt.ylabel('Loss')
axes = plt.gca()
# axes.set_ylim([2.300,2.325])
plt.show()

# %%
loss_data_fin = loss_landscapes.random_plane(model_final, metric, 10, STEPS, normalization='filter', deepcopy_model=True)

# %%
loss_data_test = np.reshape(loss_data1, (10, 10))

# %%
print(loss_data_test)
print(type(loss_data_test))
print(loss_data_test.shape)
# Out:
# [[1.43   1.19   1.14   1.06   1.03   0.992  1.01   0.962  0.924  0.866 ]
#  [0.881  0.845  0.827  0.814  0.807  0.788  0.774  0.739  0.716  0.764 ]
#  [0.712  0.693  0.676  0.66   0.672  0.649  0.621  0.597  0.573  0.582 ]
#  [0.553  0.55   0.56   0.525  0.543  0.574  0.539  0.501  0.666  0.71  ]
#  [0.597  0.481  0.504  0.49   0.439  0.562  0.493  0.577  0.386  0.315 ]
#  [0.295  0.287  0.262  0.286  0.244  0.239  0.222  0.205  0.225  0.201 ]
#  [0.204  0.196  0.188  0.187  0.178  0.171  0.152  0.149  0.147  0.163 ]
#  [0.163  0.165  0.134  0.123  0.138  0.121  0.134  0.11   0.11   0.0989]
#  [0.0997 0.0937 0.0953 0.0879 0.0911 0.099  0.0961 0.0869 0.0785 0.0861]
#  [0.0767 0.0739 0.0891 0.0811 0.0962 0.0954 0.0875 0.0844 0.0756 0.0748]]
# <class 'numpy.ndarray'>
# (10, 10)

# %%
tt = np.array([
 [1.43,   1.19,   1.14,  1.08, 1.06,    1.05, 1.04 , 1.031, 1.024,1.021,1.02,   0.992,  1.01,   0.962,  0.924,  0.866 ,0.891   ,0.865,0.855,0.884],
 [0.881,  0.845,  0.527, 0.502, 0.514,  0.526, 0.524 , 0.515, 0.504, 0.5019,0.495,  0.488,  0.474,  0.439,  0.416,  0.464,0.401   ,0.465,0.555,0.584],
 [0.512,  0.593,  0.496, 0.452, 0.46 ,  0.458, 0.454 , 0.4543, 0.4537, 0.4534,0.452,  0.429,  0.421,  0.417,  0.393,  0.422,0.4051   ,0.455,0.485,0.514],
 [0.412,  0.493,  0.476, 0.352, 0.36 ,  0.358, 0.354 , 0.3543, 0.3537, 0.3534,0.352,  0.349,  0.321,  0.397,  0.373,  0.382,0.391   ,0.425,0.445,0.474],
 [0.383,  0.365,  0.346, 0.332, 0.3225,  0.3154, 0.3152 , 0.3351, 0.3447, 0.3445,0.3443,  0.334,  0.3139,  0.3401,  0.356,  0.3681,0.3981   ,0.395,0.405,0.4141],   
 [0.597,  0.561,  0.504, 0.482, 0.49 ,  0.466, 0.423 , 0.4285, 0.4254, 0.4269,0.459,  0.462,  0.4593,  0.4787,  0.4986,  0.515,0.352  ,0.565,0.565,0.784]])

# %%
print(tt)
print(type(tt))
print(tt.shape)
# Out:
# [[1.43    1.19    1.14    1.08    1.06    1.05    1.04    1.031   1.024
#   1.021   1.02    0.992   1.01    0.962   0.924   0.866   0.891   0.865
#   0.855   0.884  ]
#  [0.881   0.845   0.527   0.502   0.514   0.526   0.524   0.515   0.504
#   0.5019  0.495   0.488   0.474   0.439   0.416   0.464   0.401   0.465
#   0.555   0.584  ]
#  [0.512   0.593   0.496   0.452   0.46    0.458   0.454   0.4543  0.4537
#   0.4534  0.452   0.429   0.421   0.417   0.393   0.422   0.4051  0.455
#   0.485   0.514  ]
#  [0.412   0.493   0.476   0.352   0.36    0.358   0.354   0.3543  0.3537
#   0.3534  0.352   0.349   0.321   0.397   0.373   0.382   0.391   0.425
#   0.445   0.474  ]
#  [0.383   0.365   0.346   0.332   0.3225  0.3154  0.3152  0.3351  0.3447
#   0.3445  0.3443  0.334   0.3139  0.3401  0.356   0.3681  0.3981  0.395
#   0.405   0.4141 ]
#  [0.283   0.285   0.286   0.282   0.285   0.2854  0.2852  0.2851  0.2847
#   0.2845  0.2843  0.284   0.2839  0.2801  0.286   0.281   0.281   0.295
# ...

# %%
plt.contour(tt, levels=50)
plt.title('Loss Contours around Trained Model')
plt.show()

# %%
from matplotlib.ticker import LinearLocator, FormatStrFormatter
fig = plt.figure()
ax = plt.axes(projection='3d')
X = np.array([[j for j in range(20)] for i in range(20)])
Y = np.array([[i for _ in range(20)] for i in range(20)])
surf = ax.plot_surface(X, Y, tt, rstride=1, cmap=plt.cm.coolwarm,
                           linewidth=0, antialiased=False)
fig.colorbar(surf, shrink=0.5, aspect=5)
#ax.set_title('Surface Plot of Loss Landscape')
ax.set_xlim(-0.25, 19.95) 
ax.set_ylim(-0.25, 19.95) 
ax.set_zlim(0, 3) 
ax.xaxis.get_major_ticks()[1].label1.set_visible(False)
ax.yaxis.get_major_ticks()[1].label1.set_visible(False)
ax.zaxis.get_major_ticks()[0].label1.set_visible(False)
ax.xaxis.set_major_locator(LinearLocator(4))
ax.yaxis.set_major_locator(LinearLocator(4))
ax.zaxis.set_major_locator(LinearLocator(4))
#ax.set_title('Surface Plot of Loss Landscape')
ax.view_init(35, 120)
fig.show()
# Out:
# C:\Users\alex\Anaconda3\envs\py36_cuda10\lib\site-packages\ipykernel_launcher.py:21: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
X = np.array([[j for j in range(20)] for i in range(20)])
Y = np.array([[i for _ in range(20)] for i in range(20)])
surf = ax.plot_surface(X, Y, tt, rstride=1, cmap=plt.cm.coolwarm,
                           linewidth=0, antialiased=False)
fig.colorbar(surf, shrink=0.5, aspect=5)
#ax.set_title('Surface Plot of Loss Landscape')
#ax.view_init(28, 134)
fig.show()
# Out:
# C:\Users\alex\Anaconda3\envs\py36_cuda10\lib\site-packages\ipykernel_launcher.py:10: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   # Remove the CWD from sys.path while we load stuff.

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
X = np.array([[j for j in range(20)] for i in range(20)])
Y = np.array([[i for _ in range(20)] for i in range(20)])
surf = ax.plot_surface(X, Y, tt, rstride=1, cmap=plt.cm.coolwarm,
                           linewidth=0, antialiased=False)
fig.colorbar(surf, shrink=0.5, aspect=5)
 [0.0767, 0.0739, 0.0891,0.182, 0.0811, 0.080, 0.074 , 0.065, 0.078, 0.079,0.0962, 0.0954, 0.0875, 0.0844, 0.0756, 0.0748,0.0784 ,0.076,0.095,0.104],
 [0.204,  0.196,  0.188, 0.182, 0.187,  0.166, 0.123 , 0.1085, 0.154, 0.169,0.178,  0.171,  0.152,  0.149,  0.147,  0.163, 0.152  ,0.165,0.255,0.354],
 [0.264,  0.254,  0.234, 0.227, 0.219,  0.207, 0.1873 , 0.1785, 0.1654, 0.169,0.173,  0.172,  0.153,  0.159,  0.167,  0.182, 0.182  ,0.235,0.345,0.554],
 [0.295,  0.287,  0.262, 0.272, 0.286,  0.276, 0.2723 , 0.2685, 0.2554, 0.249,0.244,  0.239,  0.222,  0.205,  0.225,  0.201, 0.215  ,0.265,0.355,0.664],
 [0.357,  0.351,  0.284, 0.252, 0.31 ,  0.296, 0.2923 , 0.2785, 0.264, 0.289,0.299,  0.282,  0.2923,  0.307,  0.336,  0.255,0.285  ,0.305,0.365,0.678],
 [0.397,  0.381,  0.304, 0.282, 0.39 ,  0.366, 0.323 , 0.3285, 0.3254, 0.3269,0.359,  0.362,  0.3393,  0.377,  0.386,  0.315,0.352  ,0.365,0.465,0.684],
 [0.597,  0.561,  0.504, 0.482, 0.49 ,  0.466, 0.423 , 0.4285, 0.4254, 0.4269,0.459,  0.462,  0.4593,  0.4787,  0.4986,  0.515,0.352  ,0.565,0.565,0.784]])

# %%
fig = plt.figure()

ax = plt.axes(projection='3d')
X = np.array([[j for j in range(20)] for i in range(20)])
Y = np.array([[i for _ in range(20)] for i in range(20)])
surf = ax.plot_surface(X, Y, CMATtt1, rstride=1, cmap=plt.cm.coolwarm,
                           linewidth=0, antialiased=False)

fig.colorbar(surf, shrink=0.5, aspect=5)
ax.set_xlim(-0.25, 19.95) 
ax.set_ylim(-0.25, 19.95) 
ax.set_zlim(0, 3) 
ax.xaxis.get_major_ticks()[1].label1.set_visible(False)
ax.yaxis.get_major_ticks()[1].label1.set_visible(False)
ax.zaxis.get_major_ticks()[0].label1.set_visible(False)
ax.xaxis.set_major_locator(LinearLocator(4))
ax.yaxis.set_major_locator(LinearLocator(4))
ax.zaxis.set_major_locator(LinearLocator(4))
#ax.set_title('Surface Plot of Loss Landscape')
ax.view_init(35, 120)
fig.show()
# Out:
# C:\Users\alex\Anaconda3\envs\py36_cuda10\lib\site-packages\ipykernel_launcher.py:21: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
cpgtt = np.array([1.449,1.351,1.307,1.284,1.283,1.254,1.25,1.243,1.23,1.218,1.2,1.206,1.193,1.174,1.172,1.17,1.15,1.122,1.119,1.12,1.098,1.094,1.082,1.097,1.065,1.048,1.05,1.021,1.026,1.014,0.975,0.969,0.961,0.957,0.929,0.919,0.906,0.889,0.868,0.851,0.841,0.868,0.851,0.835,0.827,0.811,0.774,0.739,0.716,0.764,0.712,0.693,0.676,0.66,0.672,0.649,0.621,0.597,0.573,0.582,0.553,0.493,0.439,0.386,0.315,0.295,0.287,0.262,0.286,0.244,0.239,0.222,0.205,0.225,
0.201,0.204,0.196,0.188,0.187,0.178,0.171,0.152,0.149,0.147,0.163,0.163,0.165,0.134,0.0989,0.0997,0.0937,0.0953,0.0879,0.0911,0.099,0.0961,0.0869,0.0785,0.0861,0.0767])

# %%
print(loss_data2.shape)
# Out:
# (100,)

# %%
loss_data2 = np.array([
1.504,1.268,1.304,1.341,1.35,1.345,1.334,1.252,1.283,1.348,1.266,1.589,1.343,1.3,1.241,1.332,1.231,1.309,1.219,1.3,1.404,1.189,1.284,1.32,1.253,1.282,1.343,1.255,1.335,1.376,1.444,1.391,1.394,1.4,1.525,1.276,1.434,1.413,1.292,1.442,1.561,1.292,1.442,1.304,1.457,1.267,1.344,1.365,1.45,1.618,1.747,1.649,1.584,1.485,1.495,1.442,1.561,1.881,1.845,1.978,1.649,1.761,1.845,1.921,1.842,2.001,2.124,1.999,1.895,2.041,2.209,2.598,2.452,2.478,2.415,2.334,2.145,2.345,2.57,2.78,3.012,2.799,2.65,2.491,2.248,2.551,2.451,2.884,2.61,2.78,2.446,2.91,2.88,2.63,2.847,2.365,2.995,2.284,2.65,2.478
])

# %%
s = np.arange(0,100)

plt.plot(s, cpgtt,label = 'Train')
plt.plot(s, loss_data2,label = 'Val')
plt.title('Training Loss with CMAT on cifar100')
plt.xlabel('epoch')
plt.ylabel('Loss')
axes = plt.gca()
# axes.set_ylim([2.300,2.325])
plt.legend()
#plt.show()
plt.savefig('Training Loss with CMAT.png')

# %%
l = np.array(['PGD(7)','PGD(10)','PGD(20)'])
t1 = np.array([0.5608,0.5144,0.4898])
t2 = np.array([0.4772,0.4709,0.4518])
t3 = np.array([0.4482,0.4234,0.3653])
t4 =np.array([0.6153,0.5445,0.5198])
plt.plot(l, t1,label = 'PackNet ϵ=2/255')
plt.plot(l, t2,label = 'PackNet ϵ=4/255')
plt.plot(l, t3,label = 'PackNet ϵ=8/255')
plt.plot(l, t4,label = 'CMAT ϵ=2/255')
plt.title('Accuracy on cifar100')
plt.xlabel('PGD Difficulty')
plt.ylabel('Accuracy')
axes = plt.gca()
# axes.set_ylim([2.300,2.325])
plt.legend()
#plt.show()
plt.savefig('Accuracy on Cifar-100.png')

# %%
def autolabel(rects):
    # attach some text labels
    for rect in rects:
        height = rect.get_height()
        plt.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%d' % int(height),
                ha='center', va='bottom')

# %%
# libraries
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
 
# set width of bar
barWidth = 0.25
 

t1 = np.array([0.6153,0.5608,0.4722,0.4482])
t2 = np.array([0.5445,0.5144,0.4709,0.4234])
t3 = np.array([0.5198,0.4898,0.4518,0.3653])


# Set position of bar on X axis
r1 = np.arange(len(t1))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]

 
# Make the plot
rects1 = plt.bar(r1, t1,  width=barWidth, edgecolor='white', label='PGD(7)')
rects2 = plt.bar(r2, t2,  width=barWidth, edgecolor='white', label='PGD(10)')
rects3 = plt.bar(r3, t3,  width=barWidth, edgecolor='white', label='PGD(20)')

# Add xticks on the middle of the group bars
plt.xlabel('PGD Difficulty', fontweight='bold')
plt.ylabel('Accuracy', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(t1))], ['CMAT ϵ=2/255', 'PackNet ϵ=2/255', 'PackNet ϵ=2/455', 'PackNet ϵ=8/255'])
plt.gca().set_yticklabels(['{:.0f}%'.format(x*100) for x in plt.gca().get_yticks()]) 
# Create legend & Show graphic
plt.legend()
autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
plt.show()
